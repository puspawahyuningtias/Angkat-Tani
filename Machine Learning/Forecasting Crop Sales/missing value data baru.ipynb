# %%
import pandas as pd
data = pd.read_csv('data baru .csv')

data.head()
# Out:
#       Tanggal  Beras  Beras Kualitas Bawah I (kg)  \
# 0  30/04/2021  11750                        10750
# 1  03/05/2021  11750                        10750
# 2  04/05/2021  11750                        10750
# 3  05/05/2021  11750                        10750
# 4  06/05/2021  11750                        10750
#
#    Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# 0                         10400                         11800
# 1                         10400                         11800
# 2                         10400                         11800
# 3                         10400                         11800
# 4                         10400                         11800
#
#    Beras Kualitas Medium II (kg)  Beras Kualitas Super I (kg)  \
# 0                          11550                        13050
# 1                          11550                        13050
# 2                          11550                        13050
# ...

# %%
data['Tanggal'] = pd.to_datetime(data['Tanggal'], infer_datetime_format=True)

# %%
data = data.set_index('Tanggal')

# %%
data
# Out:
#             Beras  Beras Kualitas Bawah I (kg)  Beras Kualitas Bawah II (kg)  \
# Tanggal
# 2021-04-30  11750                        10750                         10400
# 2021-05-03  11750                        10750                         10400
# 2021-05-04  11750                        10750                         10400
# 2021-05-05  11750                        10750                         10400
# 2021-05-06  11750                        10750                         10400
# 2021-05-07  11750                        10750                         10400
# 2021-05-10  11750                        10700                         10400
# 2021-05-11  11750                        10700                         10400
# 2021-05-17  11750                        10700                         10400
# 2021-05-18  11750                        10700                         10400
# 2021-05-19  11750                        10750                         10400
# ...

# %% [markdown]
# method to handle missing value in time series data
#
# - drop
# - ffill
# - bfill
# - rolling window fill
# - offset fill
# - interpolate

# %% [markdown]
# ### Interpolate missing value

# %%
df = data.interpolate()

# %%
data
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# 2021-04-30  11750.0                      10750.0
# 2021-05-01      NaN                          NaN
# 2021-05-02      NaN                          NaN
# 2021-05-03  11750.0                      10750.0
# 2021-05-04  11750.0                      10750.0
# 2021-05-05  11750.0                      10750.0
# 2021-05-06  11750.0                      10750.0
# 2021-05-07  11750.0                      10750.0
# 2021-05-08      NaN                          NaN
# 2021-05-09      NaN                          NaN
# 2021-05-10  11750.0                      10700.0
# 2021-05-11  11750.0                      10700.0
# 2021-05-12      NaN                          NaN
# 2021-05-13      NaN                          NaN
# 2021-05-14      NaN                          NaN
# 2021-05-15      NaN                          NaN
# 2021-05-16      NaN                          NaN
# 2021-05-17  11750.0                      10700.0
# ...

# %%
df
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# 2021-04-30  11750.0                 10750.000000
# 2021-05-01  11750.0                 10750.000000
# 2021-05-02  11750.0                 10750.000000
# 2021-05-03  11750.0                 10750.000000
# 2021-05-04  11750.0                 10750.000000
# 2021-05-05  11750.0                 10750.000000
# 2021-05-06  11750.0                 10750.000000
# 2021-05-07  11750.0                 10750.000000
# 2021-05-08  11750.0                 10733.333333
# 2021-05-09  11750.0                 10716.666667
# 2021-05-10  11750.0                 10700.000000
# 2021-05-11  11750.0                 10700.000000
# 2021-05-12  11750.0                 10700.000000
# 2021-05-13  11750.0                 10700.000000
# 2021-05-14  11750.0                 10700.000000
# 2021-05-15  11750.0                 10700.000000
# 2021-05-16  11750.0                 10700.000000
# 2021-05-17  11750.0                 10700.000000
# ...

# %%
df.to_csv('bln5_2021.csv')

# %%
df.columns == data.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
data = pd.read_csv('cleaned_data_pangan.csv')

data.tail()
# Out:
#          Tanggal    Beras  Beras Kualitas Bawah I (kg)  \
# 1365  2021-04-26  11750.0                      10750.0
# 1366  2021-04-27  11750.0                      10750.0
# 1367  2021-04-28  11750.0                      10750.0
# 1368  2021-04-29  11750.0                      10750.0
# 1369  2021-04-30  11750.0                      10750.0
#
#       Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# 1365                       10450.0                       11800.0
# 1366                       10450.0                       11800.0
# 1367                       10450.0                       11800.0
# 1368                       10400.0                       11750.0
# 1369                       10400.0                       11800.0
#
#       Beras Kualitas Medium II (kg)  Beras Kualitas Super I (kg)  \
# 1365                        11600.0                      13050.0
# 1366                        11600.0                      13050.0
# ...

# %%
data['Tanggal'] = pd.to_datetime(data['Tanggal'], infer_datetime_format=True)

# %%
data = data.set_index('Tanggal')

# %%
data.shape
# Out:
# (1370, 17)

# %%
data = data.iloc[:-1,:]

# %%
data.shape
# Out:
# (1369, 17)

# %%
data
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# Tanggal
# 2017-07-31  11200.0                      10150.0
# 2017-08-01  11200.0                      10150.0
# 2017-08-02  11200.0                      10150.0
# 2017-08-03  11200.0                      10150.0
# 2017-08-04  11300.0                      10150.0
# ...             ...                          ...
# 2021-04-25  11750.0                      10750.0
# 2021-04-26  11750.0                      10750.0
# 2021-04-27  11750.0                      10750.0
# 2021-04-28  11750.0                      10750.0
# 2021-04-29  11750.0                      10750.0
#
#             Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# Tanggal
# 2017-07-31                        9650.0                       11250.0
# 2017-08-01                        9650.0                       11250.0
# 2017-08-02                        9650.0                       11250.0
# ...

# %%
semua = pd.concat([data, df])

# %%
semua.shape
# Out:
# (1398, 17)

# %%
semua['2021-04-29':'2021-05-4']
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# 2021-04-29  11750.0                      10750.0
# 2021-04-30  11750.0                      10750.0
# 2021-05-01  11750.0                      10750.0
# 2021-05-02  11750.0                      10750.0
# 2021-05-03  11750.0                      10750.0
# 2021-05-04  11750.0                      10750.0
#
#             Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# 2021-04-29                       10400.0                       11750.0
# 2021-04-30                       10400.0                       11800.0
# 2021-05-01                       10400.0                       11800.0
# 2021-05-02                       10400.0                       11800.0
# 2021-05-03                       10400.0                       11800.0
# 2021-05-04                       10400.0                       11800.0
#
#             Beras Kualitas Medium II (kg)  Beras Kualitas Super I (kg)  \
# ...

# %%
semua.shape
# Out:
# (1398, 17)

# %%
semua.to_csv('semua.csv')
